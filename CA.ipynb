# %% [markdown]
# <a href="https://colab.research.google.com/github/aliciaseidou/Data-ACQ/blob/main/CA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')

import os
os.chdir("/content/drive/MyDrive/Colab Notebooks/Data Acquistion/CA")
# !pwd
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/Colab Notebooks/Data Acquistion/CA

# %%
import pandas as pd

# %% [markdown]
# **Abstract**
#
# My project focuses on the dataset - songs_normalise.csv(https://www.kaggle.com/code/abdelrahman16/spotify-analysis-visualization),
#  this has multiple songs published from different years and there features such as there acousticness, loudness and tempo.
#
# I scraped a dataset from a website- kworb.net, which is all about music data. From this dataset I scraped the artists name and the country they are most famous in.
#
# I joined these two datasets together using inner join & completed visualisations using the Seaborn library

# %% [markdown]
# **Read in Kaggle Dataset**

# %%
df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Data Acquistion/CA/songs_normalize.csv")
df
# Out:
#               artist                                    song  duration_ms  \
# 0     Britney Spears                  Oops!...I Did It Again       211160
# 1          blink-182                    All The Small Things       167066
# 2         Faith Hill                                 Breathe       250546
# 3           Bon Jovi                            It's My Life       224493
# 4             *NSYNC                             Bye Bye Bye       200560
# ...              ...                                     ...          ...
# 1995  Jonas Brothers                                  Sucker       181026
# 1996    Taylor Swift                            Cruel Summer       178426
# 1997    Blanco Brown                              The Git Up       200593
# 1998       Sam Smith  Dancing With A Stranger (with Normani)       171029
# 1999     Post Malone                                 Circles       215280
#
#       explicit  year  popularity  danceability  energy  key  loudness  mode  \
# ...

# %% [markdown]
# **Exploration of DF**

# %% [markdown]
# Let's look into what each feature means(from kaggle description):
#
# artist: Name of the Artist.
#
# song: Name of the Track.
#
# duration_ms: Duration of the track in milliseconds.
#
# explicit: The lyrics or content of a song or a music video contain one or more of the criteria which could be considered offensive or unsuitable for children.
#
# year: Release Year of the track.
#
# popularity: The higher the value the more popular the song is.
#
# danceability: Danceability describes how suitable a track is for dancing based on a combination of musical elements including tempo, rhythm stability, beat strength, and overall regularity. A value of 0.0 is least danceable and 1.0 is most danceable.
#
# energy: Energy is a measure from 0.0 to 1.0 and represents a perceptual measure of intensity and activity.
#
# key: The key the track is in. Integers map to pitches using standard Pitch Class notation. E.g. 0 = C, 1 = C♯/D♭, 2 = D, and so on. If no key was detected, the value is -1.
#
# loudness: The overall loudness of a track in decibels (dB). Loudness values are averaged across the entire track and are useful for comparing relative loudness of tracks. Loudness is the quality of a sound that is the primary psychological correlate of physical strength (amplitude). Values typically range between -60 and 0 db.
#
# mode: Mode indicates the modality (major or minor) of a track, the type of scale from which its melodic content is derived. Major is represented by 1 and minor is 0.
#
# speechiness: Speechiness detects the presence of spoken words in a track. The more exclusively speech-like the recording (e.g. talk show, audio book, poetry), the closer to 1.0 the attribute value. Values above 0.66 describe tracks that are probably made entirely of spoken words. Values between 0.33 and 0.66 describe tracks that may contain both music and speech, either in sections or layered, including such cases as rap music. Values below 0.33 most likely represent music and other non-speech-like tracks.
#
# acousticness: A confidence measure from 0.0 to 1.0 of whether the track is acoustic. 1.0 represents high confidence the track is acoustic.
#
# instrumentalness: Predicts whether a track contains no vocals. "Ooh" and "aah" sounds are treated as instrumental in this context. Rap or spoken word tracks are clearly "vocal". The closer the instrumentalness value is to 1.0, the greater likelihood the track contains no vocal content. Values above 0.5 are intended to represent instrumental tracks, but confidence is higher as the value approaches 1.0.
#
# liveness: Detects the presence of an audience in the recording. Higher liveness values represent an increased probability that the track was performed live. A value above 0.8 provides strong likelihood that the track is live.
#
# valence: A measure from 0.0 to 1.0 describing the musical positiveness conveyed by a track. Tracks with high valence sound more positive (e.g. happy, cheerful, euphoric), while tracks with low valence sound more negative (e.g. sad, depressed, angry).
#
# tempo: The overall estimated tempo of a track in beats per minute (BPM). In musical terminology, tempo is the speed or pace of a given piece and derives directly from the average beat duration.
#
# genre: Genre of the track.

# %%
df.shape
# Out:
# (2000, 18)

# %% [markdown]
# **How do metrics correlate with eachother? (Heatmap)**

# %%
plt.figure(figsize=(8, 6))  # Optional: Adjust the figure size
metric_columns = df[['acousticness', 'danceability', 'energy','loudness','liveness', 'tempo','speechiness']]
corr= metric_columns.corr()
sns.heatmap(corr, annot=True, cmap="coolwarm", linewidths=0.5, fmt=".2f")

plt.title("Heatmap of Song Metrics")
plt.show()

# %% [markdown]
# We can see that energy and loudness are highly correlated

# %% [markdown]
# **Are Explicit Songs More Popular?**

# %%
plt.figure(figsize=(14,8))

sns.barplot(x='explicit', y = 'popularity', data= df, errorbar= None)

plt.title("Are Explicit Songs More Popular?")
plt.xlabel("Explicit")
plt.ylabel("Popularity")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# Explicit Songs - True
#
# Non- Explicit - False
#
# The distributions are similar so they are assumed to be as popular as eachother

# %% [markdown]
# **What are the danceability levels of the most popular songs?**

# %%
plt.figure(figsize=(16,8))

sns.scatterplot(data=df,x="danceability",y="popularity")

plt.title("Popularity vs Danceability")
plt.xlabel("Danceability")
plt.ylabel("Popularity")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# Most Popular songs are between the danceability level of 0.55 and 0.8

# %% [markdown]
# **What Genre is the Most Popular?**

# %%
plt.figure(figsize=(16,8))

sns.barplot(x='genre', y='popularity', data= df, errorbar= None)

plt.title("What Genre is the Most Popular?")
plt.xlabel("Genre")
plt.ylabel("Popularity")
plt.tight_layout()
plt.show()

# %% [markdown]
# Most popular songs are within the Metal and Easy listening genres

# %% [markdown]
# **What acoustic level are the most popular songs?**

# %%
plt.figure(figsize=(16,8))

sns.scatterplot(data=df, x="acousticness",y="popularity")

plt.title("What acoustic level are the most popular songs?")
plt.xlabel("Acousticness")
plt.ylabel("Popularity")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# Most popular songs have an acoustic level beneath 0.1

# %% [markdown]
# **WebScraping**

# %%
# !pip install bs4

from bs4 import BeautifulSoup

# %%
import http.client
import urllib.request

http.client._MAXHEADERS = 1000

url = "https://kworb.net/itunes/"
response = urllib.request.urlopen(url)
raw_html = response.read().decode("utf-8")
soup = BeautifulSoup(raw_html, 'html.parser')
#print(soup)

# %%
def getInfoData(trnode):#create function to get data from HTML
    datarow = {} #create dictonary for data
    datarow["artist"] = trnode.find_all("a")[0].get_text()
    datarow["top country"] = trnode.find("td", class_="bl mp smaller").get_text()
    return datarow

response = urllib.request.urlopen(url)
raw_html = response.read().decode("utf-8")
soup = BeautifulSoup(raw_html, 'html.parser')
tbodynode = soup.find("table", {"id":"artists"}).find("tbody")#locates table in HTML
country_items = []
for trnode in tbodynode.find_all("tr"):
    country_items.append(getInfoData(trnode))#adds each scraped row to list

# %%
import pprint
pprint.pprint(country_items)
# Out:
# [{'artist': 'Taylor Swift', 'top country': 'Canada'},
#  {'artist': 'ROSALÍA', 'top country': 'Spain'},
#  {'artist': 'HUNTR/X', 'top country': 'United States'},
#  {'artist': 'Bad Bunny', 'top country': 'Spain'},
#  {'artist': 'Olivia Dean', 'top country': 'Australia'},
#  {'artist': 'KPop Demon Hunters Cast', 'top country': 'Australia'},
#  {'artist': 'Sabrina Carpenter', 'top country': 'Australia'},
#  {'artist': 'Billie Eilish', 'top country': 'Netherlands'},
#  {'artist': 'Lady Gaga', 'top country': 'Germany'},
#  {'artist': 'Saja Boys', 'top country': 'United States'},
#  {'artist': 'Alex Warren', 'top country': 'Netherlands'},
#  {'artist': 'sombr', 'top country': 'Australia'},
#  {'artist': 'Drake', 'top country': 'United States'},
#  {'artist': 'EJAE', 'top country': 'Australia'},
#  {'artist': 'Beéle', 'top country': 'Colombia'},
#  {'artist': 'REI AMI', 'top country': 'Australia'},
#  {'artist': 'AUDREY NUNA', 'top country': 'Australia'},
# ...

# %%
# !pip install prettytable

# %%
from prettytable import PrettyTable
xTable = PrettyTable()
xTable.field_names = ["artist", "top country"]
xTable.align["artist"] = xTable.align["top country"] = "l"

for x in country_items:
    xTable.add_row([x["artist"], x["top country"],])
print(xTable)
# Out:
# +---------------------------------------------+-----------------------+
# | artist                                      | top country           |
# +---------------------------------------------+-----------------------+
# | Taylor Swift                                | Canada                |
# | ROSALÍA                                     | Spain                 |
# | HUNTR/X                                     | United States         |
# | Bad Bunny                                   | Spain                 |
# | Olivia Dean                                 | Australia             |
# | KPop Demon Hunters Cast                     | Australia             |
# | Sabrina Carpenter                           | Australia             |
# | Billie Eilish                               | Netherlands           |
# | Lady Gaga                                   | Germany               |
# | Saja Boys                                   | United States         |
# ...

# %% [markdown]
# **Merge Datasets**

# %%
df2 = pd.DataFrame(country_items) #changes list to Dataframe

print(df2)
# Out:
#                                 artist    top country
# 0                         Taylor Swift         Canada
# 1                              ROSALÍA          Spain
# 2                              HUNTR/X  United States
# 3                            Bad Bunny          Spain
# 4                          Olivia Dean      Australia
# ..                                 ...            ...
# 295                             Hozier         Canada
# 296                         DJ Japa NK         Brazil
# 297                           BE:FIRST          Japan
# 298  Julión Álvarez y su Norteño Banda         Mexico
# 299                         Seyi Vibez        Nigeria
#
# [300 rows x 2 columns]

# %%
#use inner join to automatically drop NaN values
#artist is common field
merged = pd.merge(df, df2, on="artist", how = "inner" )
merged
# Out:
#            artist                                               song  \
# 0          Eminem                                The Real Slim Shady
# 1         Madonna                                              Music
# 2    Mariah Carey            Thank God I Found You (feat. Joe & 98°)
# 3           Oasis                                      Go Let It Out
# 4    Mariah Carey  Against All Odds (Take A Look at Me Now) (feat...
# ..            ...                                                ...
# 392   Post Malone                                         Better Now
# 393    Ed Sheeran      Cross Me (feat. Chance the Rapper & PnB Rock)
# 394   Post Malone                        Goodbyes (Feat. Young Thug)
# 395  Taylor Swift                                       Cruel Summer
# 396   Post Malone                                            Circles
#
#      duration_ms  explicit  year  popularity  danceability  energy  key  \
# ...

# %% [markdown]
# **Visualisation**

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# **Do explicit songs perform better in some countries than others?**

# %%
#Create variable that stores popularity mean group by explicit & country columns
avg_pop = merged.groupby(['top country', 'explicit']).mean('popularity')

# %%
plt.figure(figsize=(14,8))

sns.barplot(x='top country', y='popularity',hue ='explicit',
            data=avg_pop)

plt.title("Do Explicit Songs Perform Better by Country?")
plt.xlabel("Top Country")
plt.ylabel("Popularity")
plt.xticks(rotation=45)
plt.legend(title='Explicit Content')
plt.tight_layout()
plt.show()

# %% [markdown]
# Blue = non-explicit songs
#
# Orange = explicit songs
#
# Explicit songs outperform non-explicit songs in Australia, Chile, Romania and Switzerland.
# The UK and Canada shows the opposite trend.
# The US, The Netherlands, Germany  UK, show a slight preference toward explicit tracks.

# %% [markdown]
# **Do Latin Countries enjoy higher danceability songs?**

# %%
latin_countries = ["Mexico", "Brazil", "Argentina", "Chile", "Colombia",
    "Peru", "Spain", "Venezuela", "Dominican Republic",
    "Puerto Rico", "Uruguay", "Ecuador"]
    #Create new column - if country is in list, mark as true
merged["is_latin"] = merged["top country"].isin(latin_countries)

# %%
plt.figure(figsize=(16,8))

sns.barplot(data=merged, x="top country",y="danceability",hue="is_latin",
            palette=["#4C72B0", "#FF0000"],# Blue for non-latin, orange for latin
            errorbar=None) #Gets rid of confidence interval bars


plt.title("Average Danceability by Country (Latin Countries in Red)")
plt.xlabel("Country")
plt.ylabel("Danceability")
plt.xticks(rotation=45)
plt.legend(title="Latin Country", labels=["Non-Latin", "Latin"])
plt.tight_layout()
plt.show()

# %% [markdown]
# From this graph, we can see that many Latin countries have higher average danceability scores compared to most non-Latin countries. Countries such as Chile, Mexico, Argentina, and Ecuador show noticeably higher danceability preferences.
#
# There are also non-Latin countries with a high danceability score such as Romania, Sweden and Russia.

# %% [markdown]
# **How popular were the high Valence level songs per year?**

# %%
high_val = merged[merged['valence'] > 0.7]
high_val_year = high_val.groupby(['year', 'popularity']).mean('valence')

plt.figure(figsize=(14,8))

sns.barplot(x='year', y='popularity',
            data=high_val_year, ci= None)

plt.title("What year had the most popular highest valence songs?")
plt.xlabel("year")
plt.ylabel("Popularity")
plt.xticks(rotation=45)
plt.legend(title='Explicit Content')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-3933232911.py:6: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='year', y='popularity',
# /tmp/ipython-input-3933232911.py:13: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(title='Explicit Content')

# %% [markdown]
# How popular were they in that year per country?

# %% [markdown]
# **What Genre is the Most Popular in Each Country?**

# %%
#Creates
genre_country = (merged.groupby(["top country", "genre"]).size().reset_index(name="count")
)

plt.figure(figsize=(16,8))
sns.histplot(data=genre_country,x="top country",weights="count",hue="genre", multiple="stack")
plt.xticks(rotation=45)
plt.title("Genre Distribution by Country")
plt.show()

# %% [markdown]
# From this graph, we can see that Pop music appears frequently across many countries, making it one of the most common genres overall. In the United States, Hip Hop has the highest count, indicating that many of the charting songs from this dataset belong to that genre.
#
# In Latin countries such as Colombia, Spain, Argentina, and Mexico, the Latin genre appears most often, which reflects their strong cultural preference for Latin-inspired music styles like reggaeton and Latin pop.

# %% [markdown]
# **What Level of Acousticness do the Popular Songs have in Anglophone Countries?**

# %%
english_countries = ["Australia","United States", "United Kingdom", "South Africa","Canada"]

# %%
df_english = merged[merged["top country"].isin(english_countries)]

df_english
# Out:
#            artist                                               song  \
# 2    Mariah Carey            Thank God I Found You (feat. Joe & 98°)
# 3           Oasis                                      Go Let It Out
# 4    Mariah Carey  Against All Odds (Take A Look at Me Now) (feat...
# 9    Mariah Carey                                           Loverboy
# 27     Kanye West                                        Jesus Walks
# ..            ...                                                ...
# 392   Post Malone                                         Better Now
# 393    Ed Sheeran      Cross Me (feat. Chance the Rapper & PnB Rock)
# 394   Post Malone                        Goodbyes (Feat. Young Thug)
# 395  Taylor Swift                                       Cruel Summer
# 396   Post Malone                                            Circles
#
#      duration_ms  explicit  year  popularity  danceability  energy  key  \
# ...

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x="acousticness", y="popularity", data=df_english)
plt.title("Popularity vs Acousticness for Songs in English-speaking Countries")
plt.xlabel("Acoustic Levels")
plt.ylabel("Popularity")
plt.show()

# %% [markdown]
# From this graph, we can see that most popular songs in English-speaking countries have low to moderate acousticness. The majority of songs cluster between 0.0 and 0.4, indicating that chart-topping tracks in these regions tend to be heavily produced, electronic, or beat-driven rather than acoustic. Songs with higher acousticness (0.5 and above) appear much less frequently and generally show lower popularity.

# %% [markdown]
# **Observed Issues**

# %% [markdown]
# An issue I encountered when creating my visualisations was that I only had access to each artist’s top country, not the top country for each individual song. Because of this limitation, I had to assume that every song released by an artist was also most popular in the same country as the artist’s overall top market. This may introduce inaccuracies, as individual songs can perform differently across countries.
